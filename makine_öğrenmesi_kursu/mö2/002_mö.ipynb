# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt

# %%
veriler = pd.read_csv("bilkav.com_satislar.csv")

# %%
aylar = veriler[["Aylar"]]
satislar = veriler[["Satislar"]]
satislar2 = veriler.iloc[:,:1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(aylar,satislar,test_size=0.33, random_state=0)

# %%
# from sklearn.preprocessing import StandardScaler
# sc =StandardScaler()
# X_train = sc.fit_transform(x_train)
# X_test = sc.fit_transform(x_test)
# Y_train = sc.fit_transform(y_train)
# Y_test = sc.fit_transform(y_test)

# %% [markdown]
# MODEL İNŞASI

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
tahmin = lr.predict(x_test)
# Out:
# c:\Users\emre4\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
x_train = x_train.sort_index()
y_train = y_train.sort_index()
plt.plot(x_train,y_train)

# %%
plt.plot(x_test,lr.predict(x_test))
# Out:
# c:\Users\emre4\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
